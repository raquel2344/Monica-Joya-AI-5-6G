# %% [markdown]
# # RF Propagation Modeling with Python
#
# **Monica Joya - ITAI 4370 - Laboratory 02**
#
# This notebook simulates Free-Space Path Loss (FSPL) for a 2.4 GHz WiFi signal across distances from 0.1 to 20 kilometers using the provided formula and Python code. It presents the output together with the code formula as per instructions, so the calculation and the resulting plot are visible in the same file. The chart shows how path loss in decibels rises as distance grows, illustrating the Module 2 concept of how wireless signals weaken over range.

# %% [markdown]
# ## Objective
#
# Simulate Free-Space Path Loss (FSPL) to understand wireless coverage.
#
# ## Formula
#
# $$FSPL(dB) = 20\log_{10}(d) + 20\log_{10}(f) + 32.44$$
#
# Where:
# - $d$ = distance (km)
# - $f$ = frequency (MHz)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
frequency = 2400  # MHz (2.4 GHz WiFi)
distances = np.linspace(0.1, 20, 100)  # km

# FSPL calculation
fspl = 20*np.log10(distances) + 20*np.log10(frequency) + 32.44

# Plot
plt.figure(figsize=(8,5))
plt.plot(distances, fspl, label='FSPL at 2.4 GHz')
plt.xlabel('Distance (km)')
plt.ylabel('Path Loss (dB)')
plt.title('Free-Space Path Loss vs Distance')
plt.grid(True)
plt.legend()
plt.show()
